# %% [markdown]
# <a href="https://colab.research.google.com/github/sarmad-usman/flyrank-ml-internship/blob/main/work/notebooks/w05_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sarmad-usman/flyrank-ml-internship/blob/main/work/notebooks/w05_model.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Method choice and why
#
# *Which method from the toolkit, and why it fits your lane.*

# %%
import numpy as np
import pandas as pd

# --- Your chosen method and why it fits your lane goes here ---
# For example:
# from sklearn.ensemble import RandomForestClassifier
# model = RandomForestClassifier(random_state=42)
# print("Chosen method: Random Forest Classifier because it handles non-linear relationships well.")

# %% [markdown]
# ## 2. Split design
#
# *Grouped by client? Time-aware? Say why this split is honest for your question.*

# %%
from sklearn.model_selection import train_test_split

# --- Define your split strategy here and explain why it's honest for your question ---
# For example:
# X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42, stratify=target)
# print("Split design: A stratified random split was chosen to ensure representation of all target classes in both training and test sets.")

# If your data requires a time-aware split:
# train_data = data[data['date'] < split_date]
# test_data = data[data['date'] >= split_date]
# print("Split design: A time-aware split was used to simulate real-world data availability and prevent data leakage from the future.")

# If your data needs a grouped split (e.g., by client):
# from sklearn.model_selection import GroupKFold
# groups = data['client_id']
# gkf = GroupKFold(n_splits=5)
# for train_index, test_index in gkf.split(features, target, groups):
#     X_train, X_test = features.iloc[train_index], features.iloc[test_index]
#     y_train, y_test = target.iloc[train_index], target.iloc[test_index]
# print("Split design: GroupKFold was used to ensure that samples from the same client are not split across training and test sets, preventing data leakage.")

# %% [markdown]
# ## 3. Train + compare vs my baseline
#
# *Same data, same metric, same split as your Week-4 baseline. Show the table.*

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# --- Train your model ---
# Assuming 'model' and split data (X_train, y_train, X_test, y_test) are defined in previous cells
# model.fit(X_train, y_train)

# --- Make predictions ---
# y_pred = model.predict(X_test)
# y_proba = model.predict_proba(X_test)[:, 1] # For probabilistic metrics like ROC AUC

# --- Evaluate performance using the same metric as your Week-4 baseline ---
# For example, for classification:
# current_metric_score = accuracy_score(y_test, y_pred)
# print(f"Current Model Metric (e.g., Accuracy): {current_metric_score:.4f}")

# --- Define your baseline metric (from Week-4) ---
# week4_baseline_metric = 0.75 # Replace with your actual Week-4 baseline score
# print(f"Week-4 Baseline Metric: {week4_baseline_metric:.4f}")

# --- Compare and display results in a table ---
# import pandas as pd
# results = pd.DataFrame({
#     'Metric': ['Accuracy', 'Precision', 'Recall', 'F1-Score', 'ROC AUC'],
#     'Current Model': [accuracy_score(y_test, y_pred), precision_score(y_test, y_pred), recall_score(y_test, y_pred), f1_score(y_test, y_pred), roc_auc_score(y_test, y_proba)],
#     'Week-4 Baseline': [week4_baseline_metric, None, None, None, None] # Fill other baseline metrics if available
# })
# print("\nComparison with Baseline:")
# print(results.round(4).to_markdown(index=False))

# --- You can also add more detailed metrics or plots here ---
# from sklearn.metrics import classification_report, confusion_matrix
# print("\nClassification Report:")
# print(classification_report(y_test, y_pred))
# print("\nConfusion Matrix:")
# print(confusion_matrix(y_test, y_pred))

# %% [markdown]
# ## 4. Errors and interpretation
#
# *Where is the model wrong? What does it lean on? A short error analysis beats a big metric table.*

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
# from sklearn.inspection import permutation_importance, PartialDependenceDisplay # Uncomment if using for feature importance/PDP

# --- Error Analysis: Where is the model wrong? ---
# Assuming y_test and y_pred (and optionally y_proba) are available from the previous step

# 1. Confusion Matrix Visualization
# print("\nConfusion Matrix:")
# cm = confusion_matrix(y_test, y_pred)
# plt.figure(figsize=(6, 5))
# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
#             xticklabels=['Predicted Negative', 'Predicted Positive'],
#             yticklabels=['Actual Negative', 'Actual Positive'])
# plt.xlabel('Predicted Label')
# plt.ylabel('True Label')
# plt.title('Confusion Matrix')
# plt.show()

# 2. Analyze Misclassified Samples
# errors = X_test[y_test != y_pred]
# print(f"\nNumber of misclassified samples: {len(errors)}")
# print("\nExamples of misclassified samples (first 5):")
# print(errors.head())

# Look for patterns in misclassified samples (e.g., specific feature values, classes that are often confused)
# You might need to merge X_test with y_test and y_pred to see full context:
# misclassified_df = X_test.copy()
# misclassified_df['Actual'] = y_test
# misclassified_df['Predicted'] = y_pred
# misclassified_df = misclassified_df[misclassified_df['Actual'] != misclassified_df['Predicted']]
# print("\nDetailed view of some misclassified samples:")
# print(misclassified_df.head())

# --- Interpretation: What does the model lean on? ---

# 1. Feature Importance (for tree-based models like RandomForest, XGBoost)
# if hasattr(model, 'feature_importances_'):
#     feature_names = X_train.columns # Replace with your actual feature names if X_train is not a DataFrame
#     importances = model.feature_importances_
#     feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
#     feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
#     print("\nFeature Importances (Top 10):")
#     print(feature_importance_df.head(10).to_markdown(index=False))

#     plt.figure(figsize=(10, 6))
#     sns.barplot(x='Importance', y='Feature', data=feature_importance_df.head(10))
#     plt.title('Top 10 Feature Importances')
#     plt.show()
# else:
#     print("\nModel does not have feature_importances_ attribute (e.g., linear models, SVM). Consider other methods like Permutation Importance.")

# 2. Permutation Importance (model-agnostic)
# from sklearn.inspection import permutation_importance
# if 'X_test' in locals() and 'y_test' in locals() and 'model' in locals():
#     result = permutation_importance(model, X_test, y_test, n_repeats=10, random_state=42, n_jobs=-1)
#     sorted_idx = result.importances_mean.argsort()[::-1]
#     permutation_importance_df = pd.DataFrame({
#         'Feature': X_test.columns[sorted_idx],
#         'Importance_Mean': result.importances_mean[sorted_idx],
#         'Importance_Std': result.importances_std[sorted_idx]
#     })
#     print("\nPermutation Importances (Top 10):\n")
#     print(permutation_importance_df.head(10).to_markdown(index=False))
# else:
#     print("\nSkipping Permutation Importance: X_test, y_test, or model not defined.")

# 3. Partial Dependence Plots (PDP) (for understanding relationship between a feature and target)
# from sklearn.inspection import PartialDependenceDisplay
# if 'X_train' in locals() and 'model' in locals():
#     # Example for top 2 features, replace with features of interest
#     features_to_plot = feature_importance_df['Feature'].head(2).tolist() if 'feature_importance_df' in locals() else X_train.columns[:2].tolist()
#     print(f"\nGenerating Partial Dependence Plots for: {features_to_plot}")
#     PartialDependenceDisplay.from_estimator(model, X_train, features_to_plot, kind='average')
#     plt.suptitle('Partial Dependence Plots')
#     plt.tight_layout()
#     plt.show()
# else:
#     print("\nSkipping Partial Dependence Plots: X_train or model not defined.")

# --- Summary of findings ---
# Based on the above analysis, describe:
# - Which classes or types of samples are most often misclassified?
# - What are the key features driving the model's predictions?
# - Are there any unexpected dependencies or interactions?
# - How does this inform potential improvements or business insights?

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

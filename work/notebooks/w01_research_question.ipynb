# %% [markdown]
# <a href="https://colab.research.google.com/github/sarmad-usman/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sarmad-usman/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
my_lane = "<Your ML Lane or Research Question Here>"
print(f"My chosen ML lane: {my_lane}")
# Out:
# My chosen ML lane: <Your ML Lane or Research Question Here>

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
decision_improved = "<Decision your work improves>"
actor = "<Who acts on the decision>"
cost_of_wrong_call = "<Cost of a wrong recommendation>"

print(f"Decision Improved: {decision_improved}")
print(f"Actor: {actor}")
print(f"Cost of Wrong Call: {cost_of_wrong_call}")
# Out:
# Decision Improved: <Decision your work improves>
# Actor: <Who acts on the decision>
# Cost of Wrong Call: <Cost of a wrong recommendation>

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Assuming your starter CSV is named 'your_starter_data.csv'
# Replace with the actual path to your CSV file
try:
    df = pd.read_csv('your_starter_data.csv')
    print('Dataset loaded successfully! Here are some initial statistics:')
    print(df.describe())
    # You can also show specific numbers, e.g., for certain columns
    # print(f"Average of 'some_column': {df['some_column'].mean()}")
    # print(f"Number of unique values in 'another_column': {df['another_column'].nunique()}")
except FileNotFoundError:
    print("Error: 'your_starter_data.csv' not found. Please make sure the file is in the correct directory or update the path.")
except Exception as e:
    print(f"An error occurred while loading or processing the data: {e}")
# Out:
# Error: 'your_starter_data.csv' not found. Please make sure the file is in the correct directory or update the path.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# What my work will be able to say:
# (e.g., 'This model shows an observed correlation between X and Y.',
#  'The results provide directional insights into Z for decision-support.',
#  'The findings can help prioritize areas for further investigation.')

# What my work will NOT be able to say:
# (e.g., 'This proves causation between X and Y.',
#  'This model can predict exact future market values.',
#  'This is a definitive forecast; it's not a causal proof.',
#  'My work will not 'predict Google' or provide absolute truths, but rather informed estimations.')

# Example placeholder (remove or modify as needed):
print("My work will provide observed, directional insights to support decision-making regarding [specific decision].")
print("It will not offer causal proof, nor will it predict definitive outcomes or 'Google-level' precision.")
# Out:
# My work will provide observed, directional insights to support decision-making regarding [specific decision].
# It will not offer causal proof, nor will it predict definitive outcomes or 'Google-level' precision.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
